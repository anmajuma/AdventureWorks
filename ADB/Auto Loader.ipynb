# %%
from pyspark.sql.types import *
from delta.tables import *
from pyspark.sql.utils import AnalysisException
from pyspark.sql.functions import col
import pyspark.sql.functions as f
from pyspark.sql.functions import *
from pyspark.sql.types import *
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
customSchema = StructType([     
    StructField("PROVINCE", StringType(), True),
    StructField("REGION", StringType(), True),
    StructField("AGEGROUP", StringType(), True),
    StructField("SEX", StringType(), True),
    StructField("CASES", DoubleType(), True)
])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
configs = {"fs.azure.account.auth.type": "OAuth",
          "fs.azure.account.oauth.provider.type": "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider",
          "fs.azure.account.oauth2.client.id": "9f00cf9c-be8f-4763-9122-184ac7d8fd86",
          "fs.azure.account.oauth2.client.secret": "_V13fxqLpffKv5o3_un_31GVyFtt35A_7a",
          "fs.azure.account.oauth2.client.endpoint": "https://login.microsoftonline.com/6d37034b-3c0b-46b0-a541-2c09f979ed46/oauth2/token"}
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Optionally, you can add <directory-name> to the source URI of your mount point.
dbutils.fs.mount(source = "abfss://landing@demo343.dfs.core.windows.net/", mount_point = "/mnt/lnd", extra_configs = configs)
dbutils.fs.mount(source = "abfss://checkpoint@demo343.dfs.core.windows.net/", mount_point = "/mnt/chk", extra_configs = configs)
dbutils.fs.mount(source = "abfss://autostream@demo343.dfs.core.windows.net/", mount_point = "/mnt/strem", extra_configs = configs)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">ExecutionError</span>                            Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-1381587721403789&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-intense-fg ansi-bold">      1</span> <span class="ansi-red-fg"># Optionally, you can add &lt;directory-name&gt; to the source URI of your mount point.</span>
# <span class="ansi-green-fg">----&gt; 2</span><span class="ansi-red-fg"> </span>dbutils<span class="ansi-blue-fg">.</span>fs<span class="ansi-blue-fg">.</span>mount<span class="ansi-blue-fg">(</span>source <span class="ansi-blue-fg">=</span> <span class="ansi-blue-fg">&#34;abfss://landing@demo343.dfs.core.windows.net/&#34;</span><span class="ansi-blue-fg">,</span> mount_point <span class="ansi-blue-fg">=</span> <span class="ansi-blue-fg">&#34;/mnt/lnd&#34;</span><span class="ansi-blue-fg">,</span> extra_configs <span class="ansi-blue-fg">=</span> configs<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">      3</span> dbutils<span class="ansi-blue-fg">.</span>fs<span class="ansi-blue-fg">.</span>mount<span class="ansi-blue-fg">(</span>source <span class="ansi-blue-fg">=</span> <span class="ansi-blue-fg">&#34;abfss://checkpoint@demo343.dfs.core.windows.net/&#34;</span><span class="ansi-blue-fg">,</span> mount_point <span class="ansi-blue-fg">=</span> <span class="ansi-blue-fg">&#34;/mnt/chk&#34;</span><span class="ansi-blue-fg">,</span> extra_configs <span class="ansi-blue-fg">=</span> configs<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">      4</span> dbutils<span class="ansi-blue-fg">.</span>fs<span class="ansi-blue-fg">.</span>mount<span class="ansi-blue-fg">(</span>source <span class="ansi-blue-fg">=</span> <span class="ansi-blue-fg">&#34;abfss://autostream@demo343.dfs.core.windows.net/&#34;</span><span class="ansi-blue-fg">,</span> mount_point <span class="ansi-blue-fg">=</span> <span class="ansi-blue-fg">&#34;/mnt/strem&#34;</span><span class="ansi-blue-fg">,</span> extra_configs <span class="ansi-blue-fg">=</span> configs<span class="ansi-blue-fg">)</span>
#
# <span class="ansi-green-fg">/databricks/python_shell/dbruntime/dbutils.py</span> in <span class="ansi-cyan-fg">f_with_exception_handling</span><span class="ansi-blue-fg">(*args, **kwargs)</span>
# <span class="ansi-green-intense-fg ansi-bold">    328</span>                     exc<span class="ansi-blue-fg">.</span>__context__ <span class="ansi-blue-fg">=</span> <span class="ansi-green-fg">None</span>
# <span class="ansi-green-intense-fg ansi-bold">    329</span>                     exc<span class="ansi-blue-fg">.</span>__cause__ <span class="ansi-blue-fg">=</span> <span class="ansi-green-fg">None</span>
# <span class="ansi-green-fg">--&gt; 330</span><span class="ansi-red-fg">                     </span><span class="ansi-green-fg">raise</span> exc
# <span class="ansi-green-intense-fg ansi-bold">    331</span>             <span class="ansi-green-fg">return</span> f_with_exception_handling
# <span class="ansi-green-intense-fg ansi-bold">    332</span>
#
# <span class="ansi-red-fg">ExecutionError</span>: An error occurred while calling o315.mount.
# : java.io.FileNotFoundException: Operation failed: &#34;The specified filesystem does not exist.&#34;, 404, HEAD, https://demo343.dfs.core.windows.net/landing/?upn=false&amp;action=getAccessControl&amp;timeout=90
# 	at shaded.databricks.azurebfs.org.apache.hadoop.fs.azurebfs.AzureBlobFileSystem.checkException(AzureBlobFileSystem.java:1179)
# 	at shaded.databricks.azurebfs.org.apache.hadoop.fs.azurebfs.AzureBlobFileSystem.getFileStatus(AzureBlobFileSystem.java:520)
# 	at com.databricks.backend.daemon.dbutils.DBUtilsCore.verifyAzureFileSystem(DBUtilsCore.scala:772)
# 	at com.databricks.backend.daemon.dbutils.DBUtilsCore.mount(DBUtilsCore.scala:720)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at py4j.reflection.MethodInvoker.invoke(MethodInvoker.java:244)
# 	at py4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:380)
# 	at py4j.Gateway.invoke(Gateway.java:295)
# 	at py4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:132)
# 	at py4j.commands.CallCommand.execute(CallCommand.java:79)
# 	at py4j.GatewayConnection.run(GatewayConnection.java:251)
# 	at java.lang.Thread.run(Thread.java:748)
# Caused by: Operation failed: &#34;The specified filesystem does not exist.&#34;, 404, HEAD, https://demo343.dfs.core.windows.net/landing/?upn=false&amp;action=getAccessControl&amp;timeout=90
# 	at shaded.databricks.azurebfs.org.apache.hadoop.fs.azurebfs.services.AbfsRestOperation.execute(AbfsRestOperation.java:237)
# 	at shaded.databricks.azurebfs.org.apache.hadoop.fs.azurebfs.services.AbfsClient.getAclStatus(AbfsClient.java:767)
# 	at shaded.databricks.azurebfs.org.apache.hadoop.fs.azurebfs.services.AbfsClient.getAclStatus(AbfsClient.java:749)
# 	at shaded.databricks.azurebfs.org.apache.hadoop.fs.azurebfs.AzureBlobFileSystemStore.getIsNamespaceEnabled(AzureBlobFileSystemStore.java:303)
# 	at shaded.databricks.azurebfs.org.apache.hadoop.fs.azurebfs.AzureBlobFileSystemStore.getFileStatus(AzureBlobFileSystemStore.java:806)
# 	at shaded.databricks.azurebfs.org.apache.hadoop.fs.azurebfs.AzureBlobFileSystem.getFileStatus(AzureBlobFileSystem.java:518)
# 	... 13 more
# </div>

# %%
spark.conf.set("fs.azure.account.auth.type.demo343.dfs.core.windows.net", "OAuth")
spark.conf.set("fs.azure.account.oauth.provider.type.demo343.dfs.core.windows.net", "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider")
spark.conf.set("fs.azure.account.oauth2.client.id.demo343.dfs.core.windows.net", "9f00cf9c-be8f-4763-9122-184ac7d8fd86")
spark.conf.set("fs.azure.account.oauth2.client.secret.demo343.dfs.core.windows.net", "_V13fxqLpffKv5o3_un_31GVyFtt35A_7a")
spark.conf.set("fs.azure.account.oauth2.client.endpoint.demo343.dfs.core.windows.net", "https://login.microsoftonline.com/6d37034b-3c0b-46b0-a541-2c09f979ed46/oauth2/token")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
queuesas = "BlobEndpoint=https://demo343.blob.core.windows.net/;QueueEndpoint=https://demo343.queue.core.windows.net/;FileEndpoint=https://demo343.file.core.windows.net/;TableEndpoint=https://demo343.table.core.windows.net/;SharedAccessSignature=sv=2020-08-04&ss=q&srt=sco&sp=rwdlacup&se=2021-07-29T17:15:57Z&st=2021-07-29T09:15:57Z&spr=https,http&sig=J52BQv5Q97Lwi1sGLzxMu3%2BQ9QWEGjjtO2EMTx%2FBdow%3D"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Read JSON file into dataframe
df = spark.read.json("abfss://landingz@demo343.dfs.core.windows.net/2021-21-08")
df.printSchema()
df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- flights: array (nullable = true)
#     |-- element: struct (containsNull = true)
#     |    |-- actualLandingTime: string (nullable = true)
#     |    |-- actualOffBlockTime: string (nullable = true)
#     |    |-- aircraftRegistration: string (nullable = true)
#     |    |-- aircraftType: struct (nullable = true)
#     |    |    |-- iataMain: string (nullable = true)
#     |    |    |-- iataSub: string (nullable = true)
#     |    |-- airlineCode: long (nullable = true)
#     |    |-- baggageClaim: struct (nullable = true)
#     |    |    |-- belts: array (nullable = true)
#     |    |    |    |-- element: string (containsNull = true)
#     |    |-- checkinAllocations: string (nullable = true)
#     |    |-- codeshares: struct (nullable = true)
#     |    |    |-- codeshares: array (nullable = true)
#     |    |    |    |-- element: string (containsNull = true)
#     |    |-- estimatedLandingTime: string (nullable = true)
#     |    |-- expectedSecurityFilter: string (nullable = true)
#     |    |-- expectedTimeBoarding: string (nullable = true)
#     |    |-- expectedTimeGateClosing: string (nullable = true)
#     |    |-- expectedTimeGateOpen: string (nullable = true)
#     |    |-- expectedTimeOnBelt: string (nullable = true)
#     |    |-- flightDirection: string (nullable = true)
#     |    |-- flightName: string (nullable = true)
#     |    |-- flightNumber: long (nullable = true)
#     |    |-- gate: string (nullable = true)
#     |    |-- id: string (nullable = true)
#     |    |-- isOperationalFlight: boolean (nullable = true)
#     |    |-- lastUpdatedAt: string (nullable = true)
#     |    |-- mainFlight: string (nullable = true)
#     |    |-- pier: string (nullable = true)
#     |    |-- prefixIATA: string (nullable = true)
#     |    |-- prefixICAO: string (nullable = true)
#     |    |-- publicEstimatedOffBlockTime: string (nullable = true)
#     |    |-- publicFlightState: struct (nullable = true)
#     |    |    |-- flightStates: array (nullable = true)
#     |    |    |    |-- element: string (containsNull = true)
#     |    |-- route: struct (nullable = true)
#     |    |    |-- destinations: array (nullable = true)
#     |    |    |    |-- element: string (containsNull = true)
#     |    |    |-- eu: string (nullable = true)
#     |    |    |-- visa: boolean (nullable = true)
#     |    |-- scheduleDate: string (nullable = true)
#     |    |-- scheduleDateTime: string (nullable = true)
#     |    |-- scheduleTime: string (nullable = true)
#     |    |-- schemaVersion: string (nullable = true)
#     |    |-- serviceType: string (nullable = true)
#     |    |-- terminal: long (nullable = true)
#     |    |-- transferPositions: string (nullable = true)
#
# +--------------------+
#              flights|
# +--------------------+
# [{2021-08-21T00:3...|
# +--------------------+
#
# </div>

# %%
flightsdf= df.select(explode("flights").alias("flightdetails"))
flightsdf.printSchema()
flightsdf.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- flightdetails: struct (nullable = true)
#     |-- actualLandingTime: string (nullable = true)
#     |-- actualOffBlockTime: string (nullable = true)
#     |-- aircraftRegistration: string (nullable = true)
#     |-- aircraftType: struct (nullable = true)
#     |    |-- iataMain: string (nullable = true)
#     |    |-- iataSub: string (nullable = true)
#     |-- airlineCode: long (nullable = true)
#     |-- baggageClaim: struct (nullable = true)
#     |    |-- belts: array (nullable = true)
#     |    |    |-- element: string (containsNull = true)
#     |-- checkinAllocations: string (nullable = true)
#     |-- codeshares: struct (nullable = true)
#     |    |-- codeshares: array (nullable = true)
#     |    |    |-- element: string (containsNull = true)
#     |-- estimatedLandingTime: string (nullable = true)
#     |-- expectedSecurityFilter: string (nullable = true)
#     |-- expectedTimeBoarding: string (nullable = true)
#     |-- expectedTimeGateClosing: string (nullable = true)
#     |-- expectedTimeGateOpen: string (nullable = true)
#     |-- expectedTimeOnBelt: string (nullable = true)
#     |-- flightDirection: string (nullable = true)
#     |-- flightName: string (nullable = true)
#     |-- flightNumber: long (nullable = true)
#     |-- gate: string (nullable = true)
#     |-- id: string (nullable = true)
#     |-- isOperationalFlight: boolean (nullable = true)
#     |-- lastUpdatedAt: string (nullable = true)
#     |-- mainFlight: string (nullable = true)
#     |-- pier: string (nullable = true)
#     |-- prefixIATA: string (nullable = true)
#     |-- prefixICAO: string (nullable = true)
#     |-- publicEstimatedOffBlockTime: string (nullable = true)
#     |-- publicFlightState: struct (nullable = true)
#     |    |-- flightStates: array (nullable = true)
#     |    |    |-- element: string (containsNull = true)
#     |-- route: struct (nullable = true)
#     |    |-- destinations: array (nullable = true)
#     |    |    |-- element: string (containsNull = true)
#     |    |-- eu: string (nullable = true)
#     |    |-- visa: boolean (nullable = true)
#     |-- scheduleDate: string (nullable = true)
#     |-- scheduleDateTime: string (nullable = true)
#     |-- scheduleTime: string (nullable = true)
#     |-- schemaVersion: string (nullable = true)
#     |-- serviceType: string (nullable = true)
#     |-- terminal: long (nullable = true)
#     |-- transferPositions: string (nullable = true)
#
# +--------------------+
#        flightdetails|
# +--------------------+
# {2021-08-21T00:38...|
# {2021-08-21T00:38...|
# {2021-08-21T00:05...|
# {2021-08-21T00:05...|
# {2021-08-21T00:07...|
# {2021-08-21T00:07...|
# {2021-08-20T23:56...|
# {2021-08-20T23:56...|
# {2021-08-21T00:57...|
# {2021-08-21T00:57...|
# {2021-08-21T00:33...|
# {2021-08-21T00:33...|
# {2021-08-21T00:28...|
# {2021-08-21T00:28...|
# {2021-08-21T00:10...|
# {2021-08-21T00:10...|
# {2021-08-21T02:24...|
# {2021-08-21T02:24...|
# {2021-08-21T00:52...|
# {2021-08-21T00:52...|
# +--------------------+
#
# </div>

# %%
flight= flightsdf.select(col("flightdetails.aircraftRegistration").alias("aircraftRegistration"),col("flightdetails.airlineCode").alias("airlineCode"),col("flightdetails.flightName").alias("flightName"),col("flightdetails.flightNumber").alias("flightNumber"),explode("flightdetails.route.destinations").alias("destinations"),col("flightdetails.route.eu").alias("eu"),col("flightdetails.route.visa").alias("visa"))
flight.printSchema()
flight.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- aircraftRegistration: string (nullable = true)
# -- airlineCode: long (nullable = true)
# -- flightName: string (nullable = true)
# -- flightNumber: long (nullable = true)
# -- destinations: string (nullable = true)
# -- eu: string (nullable = true)
# -- visa: boolean (nullable = true)
#
# +--------------------+-----------+----------+------------+------------+---+-----+
# aircraftRegistration|airlineCode|flightName|flightNumber|destinations| eu| visa|
# +--------------------+-----------+----------+------------+------------+---+-----+
#                PHHXJ|        164|    HV6886|        6886|         KEF|  S|false|
#                PHHXJ|        100|    KL2745|        2745|         KEF|  S|false|
#                PHHSA|        164|    HV6334|        6334|         VLC|  S|false|
#                PHHSA|        100|    KL2579|        2579|         VLC|  S|false|
#                PHHZE|        164|    HV5428|        5428|         PSA|  S|false|
#                PHHZE|        100|    KL2581|        2581|         PSA|  S|false|
#                PHHXN|        164|    HV5766|        5766|         GRO|  S|false|
#                PHHXN|        100|    KL2526|        2526|         GRO|  S|false|
#                PHHZG|        164|    HV6822|        6822|         LJU|  S|false|
#                PHHZG|        100|    KL2572|        2572|         LJU|  S|false|
#                PHHSM|        164|    HV6308|        6308|         BEY|  N|false|
#                PHHSM|        100|    KL2742|        2742|         BEY|  N|false|
#                PHHXG|        164|    HV5314|        5314|         LCA|  E|false|
#                PHHXG|        100|    KL2756|        2756|         LCA|  E|false|
#                PHHXK|        164|    HV5760|        5760|         RAK|  N|false|
#                PHHXK|        100|    KL2628|        2628|         RAK|  N|false|
#                PHHZX|        164|    HV6146|        6146|         ALC|  S|false|
#                PHHZX|        100|    KL2642|        2642|         ALC|  S|false|
#                PHHXM|        164|    HV6110|        6110|         AGP|  S|false|
#                PHHXM|        100|    KL2664|        2664|         AGP|  S|false|
# +--------------------+-----------+----------+------------+------------+---+-----+
#
# </div>

# %%
df = spark.readStream.format("cloudFiles")\
          .option("cloudFiles.format", "json")\
          .option("cloudFiles.connectionString", queuesas)\
          .option("cloudFiles.resourceGroup", "demorg")\
          .option("cloudFiles.subscriptionId", "ac90002c-698e-4529-95d3-48e20a731732")\
          .option("cloudFiles.tenantId", "6d37034b-3c0b-46b0-a541-2c09f979ed46")\
          .option("cloudFiles.clientId", "9f00cf9c-be8f-4763-9122-184ac7d8fd86")\
          .option("cloudFiles.clientSecret", "_V13fxqLpffKv5o3_un_31GVyFtt35A_7a")\
          .option("cloudFiles.validateOptions", "false")\
          .option("cloudFiles.schemaLocation", "abfss://schema@demo343.dfs.core.windows.net/") \
          .option("checkpointLocation", "abfss://checkpoint@demo343.dfs.core.windows.net/") \
          .load("abfss://landingz@demo343.dfs.core.windows.net/")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql
CREATE TABLE covid_data
   ( PROVINCE STRING,
   REGION STRING,
   AGEGROUP STRING,
   SEX STRING,
   CASES DOUBLE)
  USING DELTA
  LOCATION 'abfss://bronze@demo343.dfs.core.windows.net/'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
def upsert_data(df, epochId):
    deltaTable = DeltaTable.forPath(spark, "abfss://bronze@demo343.dfs.core.windows.net/")
    deltaTable.alias("data").merge(
      df.alias("newData"),
      "data.PROVINCE = newData.PROVINCE and data.AGEGROUP = newData.AGEGROUP and data.SEX = newData.SEX") \
    .whenNotMatchedInsertAll() \
    .execute()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df.writeStream\
  .format("delta")\
  .trigger(once=True)\
  .foreachBatch(upsert_data)\
  .option("checkpointLocation", "abfss://checkpoint@demo343.dfs.core.windows.net/")\
  .start("abfss://bronze@demo343.dfs.core.windows.net/")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[7]: &lt;pyspark.sql.streaming.StreamingQuery at 0x7f6781e5f1c0&gt;</div>

# %%
# %sql
SELECT count(*) FROM covid_data
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(1)</th></tr></thead><tbody><tr><td>91938</td></tr></tbody></table></div>

# %%
# %sql
SELECT * FROM covid_data where PROVINCE = 'Antwerpen'  and AGEGROUP = '40-49' order by CASES
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>PROVINCE</th><th>REGION</th><th>AGEGROUP</th><th>SEX</th><th>CASES</th></tr></thead><tbody><tr><td>Antwerpen</td><td>Flanders</td><td>40-49</td><td>F</td><td>1.0</td></tr><tr><td>Antwerpen</td><td>Flanders</td><td>40-49</td><td>M</td><td>1.0</td></tr><tr><td>Antwerpen</td><td>Flanders</td><td>40-49</td><td>M</td><td>1.0</td></tr><tr><td>Antwerpen</td><td>Flanders</td><td>40-49</td><td>F</td><td>1.0</td></tr><tr><td>Antwerpen</td><td>Flanders</td><td>40-49</td><td>M</td><td>1.0</td></tr><tr><td>Antwerpen</td><td>Flanders</td><td>40-49</td><td>M</td><td>1.0</td></tr><tr><td>Antwerpen</td><td>Flanders</td><td>40-49</td><td>M</td><td>1.0</td></tr><tr><td>Antwerpen</td><td>Flanders</td><td>40-49</td><td>F</td><td>1.0</td></tr><tr><td>Antwerpen</td><td>Flanders</td><td>40-49</td><td>M</td><td>1.0</td></tr><tr><td>Antwerpen</td><td>Flanders</td><td>40-49</td><td>M</td><td>1.0</td></tr><tr><td>Antwerpen</td><td>Flanders</td><td>40-49</td><td>M</td><td>1.0</td></tr><tr><td>Antwerpen</td><td>Flanders</td><td>40-49</td><td>M</td><td>1.0</td></tr><tr><td>Antwerpen</td><td>Flanders</td><td>40-49</td><td>M</td><td>1.0</td></tr><tr><td>Antwerpen</td><td>Flanders</td><td>40-49</td><td>F</td><td>1.0</td></tr><tr><td>Antwerpen</td><td>Flanders</td><td>40-49</td><td>F</td><td>1.0</td></tr><tr><td>Antwerpen</td><td>Flanders</td><td>40-49</td><td>M</td><td>1.0</td></tr><tr><td>Antwerpen</td><td>Flanders</td><td>40-49</td><td>M</td><td>1.0</td></tr><tr><td>Antwerpen</td><td>Flanders</td><td>40-49</td><td>M</td><td>1.0</td></tr><tr><td>Antwerpen</td><td>Flanders</td><td>40-49</td><td>M</td><td>1.0</td></tr><tr><td>Antwerpen</td><td>Flanders</td><td>40-49</td><td>F</td><td>1.0</td></tr><tr><td>Antwerpen</td><td>Flanders</td><td>40-49</td><td>M</td><td>1.0</td></tr><tr><td>Antwerpen</td><td>Flanders</td><td>40-49</td><td>F</td><td>1.0</td></tr><tr><td>Antwerpen</td><td>Flanders</td><td>40-49</td><td>F</td><td>1.0</td></tr><tr><td>Antwerpen</td><td>Flanders</td><td>40-49</td><td>F</td><td>1.0</td></tr><tr><td>Antwerpen</td><td>Flanders</td><td>40-49</td><td>M</td><td>1.0</td></tr><tr><td>Antwerpen</td><td>Flanders</td><td>40-49</td><td>M</td><td>1.0</td></tr><tr><td>Antwerpen</td><td>Flanders</td><td>40-49</td><td>M</td><td>1.0</td></tr><tr><td>Antwerpen</td><td>Flanders</td><td>40-49</td><td>F</td><td>1.0</td></tr><tr><td>Antwerpen</td><td>Flanders</td><td>40-49</td><td>M</td><td>1.0</td></tr><tr><td>Antwerpen</td><td>Flanders</td><td>40-49</td><td>M</td><td>1.0</td></tr><tr><td>Antwerpen</td><td>Flanders</td><td>40-49</td><td>F</td><td>1.0</td></tr><tr><td>Antwerpen</td><td>Flanders</td><td>40-49</td><td>M</td><td>1.0</td></tr><tr><td>Antwerpen</td><td>Flanders</td><td>40-49</td><td>F</td><td>1.0</td></tr><tr><td>Antwerpen</td><td>Flanders</td><td>40-49</td><td>M</td><td>1.0</td></tr><tr><td>Antwerpen</td><td>Flanders</td><td>40-49</td><td>F</td><td>1.0</td></tr><tr><td>Antwerpen</td><td>Flanders</td><td>40-49</td><td>M</td><td>1.0</td></tr><tr><td>Antwerpen</td><td>Flanders</td><td>40-49</td><td>F</td><td>1.0</td></tr><tr><td>Antwerpen</td><td>Flanders</td><td>40-49</td><td>M</td><td>1.0</td></tr><tr><td>Antwerpen</td><td>Flanders</td><td>40-49</td><td>F</td><td>1.0</td></tr><tr><td>Antwerpen</td><td>Flanders</td><td>40-49</td><td>F</td><td>1.0</td></tr><tr><td>Antwerpen</td><td>Flanders</td><td>40-49</td><td>F</td><td>1.0</td></tr><tr><td>Antwerpen</td><td>Flanders</td><td>40-49</td><td>F</td><td>1.0</td></tr><tr><td>Antwerpen</td><td>Flanders</td><td>40-49</td><td>F</td><td>1.0</td></tr><tr><td>Antwerpen</td><td>Flanders</td><td>40-49</td><td>F</td><td>1.0</td></tr><tr><td>Antwerpen</td><td>Flanders</td><td>40-49</td><td>M</td><td>1.0</td></tr><tr><td>Antwerpen</td><td>Flanders</td><td>40-49</td><td>M</td><td>1.0</td></tr><tr><td>Antwerpen</td><td>Flanders</td><td>40-49</td><td>F</td><td>1.0</td></tr><tr><td>Antwerpen</td><td>Flan ...

# %%
# %sql drop table covid_data
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>
